# %%
pip install PySide6
# Out:
# Requirement already satisfied: PySide6 in /Users/zengyanlun/Documents/Virtual/venv/lib/python3.10/site-packages (6.11.0)
# Requirement already satisfied: shiboken6==6.11.0 in /Users/zengyanlun/Documents/Virtual/venv/lib/python3.10/site-packages (from PySide6) (6.11.0)
# Requirement already satisfied: PySide6_Essentials==6.11.0 in /Users/zengyanlun/Documents/Virtual/venv/lib/python3.10/site-packages (from PySide6) (6.11.0)
# Requirement already satisfied: PySide6_Addons==6.11.0 in /Users/zengyanlun/Documents/Virtual/venv/lib/python3.10/site-packages (from PySide6) (6.11.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from PySide6 import QtWidgets
from PySide6.QtWidgets import (
    QCheckBox,
    QComboBox,
    QDoubleSpinBox,
    QFormLayout,
    QGridLayout,
    QGroupBox,
    QHBoxLayout,
    QLabel,
    QLineEdit,
    QMainWindow,
    QPushButton,
    QScrollArea,
    QSpinBox,
    QStatusBar,
    QVBoxLayout,
    QWidget,
)
import sys

class NyWindow(QMainWindow):
    def __init__(self):
        super().__init__()
        self.setWindowTitle("NyWindow")
        self.UIG1()

    def UIG1(self):
        user = QWidget(self)
        self.setCentralWidget(user)

        user_layout = QHBoxLayout(user)
        user_layout.setSpacing(10)

        left = self.BLP()
        user_layout.addWidget(left,0)

    def BLP(self):
        scroll = QScrollArea(self)
        scroll.setWidgetResizable(True)
        scroll.setMaximumSize(300,400)
        scroll.setMinimumSize(200,300)
        panel = QWidget()
        scroll.setWidget(panel)
        layout = QVBoxLayout(panel)
        layout.setSpacing(10)

        layout.addWidget(self.CGG())
        return scroll

    def CGG(self):
        group = QGroupBox('CGG')
        layout = QGridLayout(group)
        self.comboCP = QComboBox()
        self.comboCP.setEditable(True)
        self.comboDP = QComboBox()
        self.comboDP.setEditable(True)

        self.spinCB = QSpinBox()
        self.spinCB.setRange(100,3000)
        self.spinCB.setSingleStep(100)
        layout.addWidget(QLabel('CP'),0,0)
        layout.addWidget(self.comboCP,0,1)
        layout.addWidget(QLabel('DP'),1,0)
        layout.addWidget(self.comboDP,1,1)
        layout.addWidget(QLabel('CB'),2,0)
        layout.addWidget(self.spinCB,2,1)
        return group

    if __name__ == "__main__":
        app = QtWidgets.QApplication(sys.argv)
        window = NyWindow()
        window.show()
        sys.exit(app.exec())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[21], line 22
#       2 from PySide6.QtWidgets import (
#       3     QCheckBox,
#       4     QComboBox,
#    (...)
#      18     QWidget,
#      19 )
#      20 import sys
# ---> 22 class NyWindow(QMainWindow):
#      23     def __init__(self):
#      24         super().__init__()
#
# Cell In[21], line 71, in NyWindow()
#      68     return group
#      70 if __name__ == "__main__":
# ---> 71     app = QtWidgets.QApplication(sys.argv)
#      72     window = NyWindow()
#      73     window.show()
#
# RuntimeError: libshiboken: Please destroy the QApplication singleton before creating a new QApplication instance.
